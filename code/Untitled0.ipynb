# %%
import thinkdsp
import thinkplot
import pandas
PI2 = 2 * math.pi
import numpy
import thinkstats2
import math
import dct

# %%
trianglechirp = thinkdsp.TriangleSignal()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-f218c2830c30> in <module>()
# ----> 1 trianglechirp = thinkdsp.TriangleSignal(low = 1000, high = 1500)
#
# TypeError: __init__() got an unexpected keyword argument 'high'

# %%
trianglechirp2 = thinkdsp.ExpoChirp(start = 1000, end = 1500)
s = trianglechirp2.make_wave(duration = 1.5).make_spectrum()
s.plot()

# %%
signal = thinkdsp.UncorrelatedGaussianNoise()
wave = signal.make_wave(framerate=11025)
spec = wave.make_spectrum()
spec.plot()

# %%
def corrcoef(xs, ys):
    return numpy.corrcoef(xs, ys, ddof=0)[0, 1]

def serial_corr(wave, lag=1):
    N = len(wave)
    y1 = wave.ys[lag:]
    y2 = wave.ys[:N-lag]
    corr = corrcoef(y1, y2)
    return corr

def autocorr(wave):
    """Computes and plots the autocorrelation function.

    wave: Wave
    """
    lags = range(len(wave.ys)//2)
    corrs = [serial_corr(wave, lag) for lag in lags]
    return lags, corrs

# %%
sax = thinkdsp.read_wave('100475__iluppai__saxophone-weep.wav')
lags, corrs = autocorr(sax)

# %%
def make_spectrum_from_dct(hs): 
    #dct_object is just the amps 
    amps = numpy.absolute(hs)
    N = len(hs)
    fs = numpy.arange(N) * framerate / N
    return Spectrum(amps, fs)

# %%
square = thinkdsp.SquareSignal(freq = 500, amp = 1)
s = dct(square)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-f6979af46ae9> in <module>()
#       1 square = thinkdsp.SquareSignal(freq = 500, amp = 1)
# ----> 2 s = dct(square)
#
# TypeError: 'module' object is not callable

# %%
thinkplot.plot(fs, amps)
thinkplot.config(xlim = [0, 5500])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-bee2217fd3e2> in <module>()
# ----> 1 thinkplot.plot(fs, amps)
#       2 thinkplot.config(xlim = [0, 5500])
#
# NameError: name 'fs' is not defined

# %%
square_spectrum = thinkdsp.SquareSignal(freq = 440, amp = 1).make_spectrum() 

hs = dft(square_spectrum)
hs = hs*PI2*j*

# %%
signal_1 = thinkdsp.SquareSignal(freq = 440).make_wave()
signal_1.plot()
thinkplot.config(xlim = [0, 0.01])

# %%
signal_1_s = signal_1.make_spectrum()
signal_1_s.plot()

# %%
signal_2_s= thinkdsp.CosSignal(freq = 100).make_wave().make_spectrum()
signal_2_s.plot()

# %%
def synthesize2(amps, freqs, ts):
    args = numpy.outer(ts, freqs)
    M = numpy.exp(1j * PI2 * args)
    ys = numpy.dot(M, amps)
    return ys

# %%
new = signal_1_s + signal_2_s
ts_a = numpy.linspace(0, 25, 100)
freqs = numpy.linspace(0, 1, 100)
ys = synthesize2(new, freqs, ts_a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-34f10095b29b> in <module>()
#       2 ts_a = numpy.linspace(0, 25, 100)
#       3 freqs = numpy.linspace(0, 1, 100)
# ----> 4 ys = synthesize2(new, freqs, ts_a )
#
# <ipython-input-22-c0ae238e7b57> in synthesize2(amps, freqs, ts)
#       2     args = numpy.outer(ts, freqs)
#       3     M = numpy.exp(1j * PI2 * args)
# ----> 4     ys = numpy.dot(M, amps)
#       5     return ys
#
# TypeError: unsupported operand type(s) for *: 'complex' and 'Spectrum'

# %%
new.make_wave().plot()
thinkplot.config(xlim = [0, 0.01])

# %%
def some_function(spectrum_wave)
    spectrum 

    return thinkdsp.Spectrum()
