# %%
# %matplotlib inline
# %run convenience.ipynb
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

np.set_printoptions(precision=2,suppress=True) # numpy output options

pi=np.pi
j=1j

# %% [markdown]
# ### System characterization with Bode plot, step response and pole-zero map

# %%
#H = s/(s+1)
combinedplot(signal.lti([1,0], [1,1]))

# %%
# H = s/(s^2+100s+1)
combinedplot(signal.lti([1, 0], [1,100,1])) #TODO: specify range of frequencies and/or time step manually. 
#Those strange beats in the step response DO NOT EXIST. They are an illusion. Be careful.
# Out:
# /home/casey/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:475: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
# H = s/(s^2 + s + 1)
combinedplot(signal.lti([1, 0], [1,1,1]))

# %%
# H = s/(s^2 + 0.1s + 1)
combinedplot(signal.lti([1, 0], [1,0.1,1]))

# %%
# H = (s^2-0.01s+1)/(s^2 + 0.01s + 1)
combinedplot(signal.lti([1,-0.01,1], [1,0.01,1]))

# %%
# H = (s^2+0.1s+1)/(s^2 + 0.11s + 1)
combinedplot(signal.lti([1,0.1,1], [1,0.11,1]))
